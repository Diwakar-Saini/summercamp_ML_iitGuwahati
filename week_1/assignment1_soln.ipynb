# %% [markdown]
# # SUMMER ANALYTICS 2024

# %% [markdown]
# # Week-1 Assignment

# %% [markdown]
# ![493179.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # **Data Grand Prix!**

# %% [markdown]
# **Welcome to your first assignment of Summer Analytics 2025! We hope you are excited to implement and test everything you have learnt up until now. The dataset which you'll use includes information about cars.**
#
# **We've got an interesting set of questions for you to get a basic understanding of pandas and data visualization libraries. GOOD LUCK!**
#
#
# ***Let's get started with importing numpy, pandas, seaborn and matplotlib!***
#
# Note - matplotlib should be imported with the command :
#
#  `import matplotlib.pyplot as plt`

# %% [markdown]
# ![image.avif](data:image/avif;base64,...)

# %% [markdown]
# **So lets get started!! Buckle up your belts for this exciting ride!!**

# %% [markdown]
# ### 1) Start by importing all important libraries
# For eg, "import numpy as np"

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# ### 2) Read the csv file and assign it to a variable .

# %%
#your code here
dp=pd.read_csv("Cars.csv")

# %% [markdown]
# ### 3) Display shape of dataframe
# Expected Output - (398, 9)

# %%
#your code here
dp.shape
# Out:
# (398, 9)

# %% [markdown]
# ### 4) Print all columns of dataframe
# Return an array containing names of all the columns.

# %%
#your code here


dp.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin', 'name'],
#       dtype='object')

# %% [markdown]
# ### 6) Set the 'name' column as the index of dataframe

# %%
#your code here\
df = dp.set_index('name')

# %% [markdown]
# ###  7) Print a list of all the unique mpg values

# %%
#your code here
unique_mpg = dp['mpg'].unique()
print("Unique MPG values:", unique_mpg)
# Out:
# Unique MPG values: [18.  15.  16.  17.  14.  24.  22.  21.  27.  26.  25.  10.  11.   9.
#  28.  19.  12.  13.  23.  30.  31.  35.  20.  29.  32.  33.  17.5 15.5
#  14.5 22.5 24.5 18.5 29.5 26.5 16.5 31.5 36.  25.5 33.5 20.5 30.5 21.5
#  43.1 36.1 32.8 39.4 19.9 19.4 20.2 19.2 25.1 20.6 20.8 18.6 18.1 17.7
#  27.5 27.2 30.9 21.1 23.2 23.8 23.9 20.3 21.6 16.2 19.8 22.3 17.6 18.2
#  16.9 31.9 34.1 35.7 27.4 25.4 34.2 34.5 31.8 37.3 28.4 28.8 26.8 41.5
#  38.1 32.1 37.2 26.4 24.3 19.1 34.3 29.8 31.3 37.  32.2 46.6 27.9 40.8
#  44.3 43.4 36.4 44.6 40.9 33.8 32.7 23.7 23.6 32.4 26.6 25.8 23.5 39.1
#  39.  35.1 32.3 37.7 34.7 34.4 29.9 33.7 32.9 31.6 28.1 30.7 24.2 22.4
#  34.  38.  44. ]

# %% [markdown]
# ### 8) Create a column which contains the horsepower divided by weightas its metric and make this new column the index.

# %%
#your code here
dp['hp_to_weight'] = dp['horsepower'] / dp['weight']

# Set the new column as index
dp.set_index('hp_to_weight', inplace=True)

# Display the modified DataFrame
print(dp.head())
# Out:
#                mpg  cylinders  displacement  horsepower  weight  acceleration  \
# hp_to_weight
# 0.037100      18.0          8         307.0       130.0    3504          12.0
# 0.044679      15.0          8         350.0       165.0    3693          11.5
# 0.043655      18.0          8         318.0       150.0    3436          11.0
# 0.043694      16.0          8         304.0       150.0    3433          12.0
# 0.040591      17.0          8         302.0       140.0    3449          10.5
#
#               model_year origin                       name
# hp_to_weight
# 0.037100              70    usa  chevrolet chevelle malibu
# 0.044679              70    usa          buick skylark 320
# 0.043655              70    usa         plymouth satellite
# 0.043694              70    usa              amc rebel sst
# 0.040591              70    usa                ford torino

# %% [markdown]
# ![OIP (1).jpg](data:image/jpeg;base64,...)

# %% [markdown]
#  **Checkpoint!!
# Congratulations on making it this far. You are really keeping up in Data Grand Prix.
# Now starts the real race i.e. graded questions of the quiz.**

# %% [markdown]
# ## GRADED Questions (To be answered in the quiz)
# ### Try to retrieve some information from the data and answer the questions below . BEST OF LUCK !!

# %% [markdown]
# ### 1. What is name of car that has the highest horsepower?

# %%
max_hp_row = dp.loc[dp['horsepower'].idxmax()]

print("Car with highest horsepower:", car_with_max_hp)
# Out:
# Car with highest horsepower: pontiac grand prix

# %% [markdown]
# ### 2. How many cars have mpg ≥ 35?

# %%
#your code here
high_mpg_count = (df['mpg'] >= 35).sum()
print(f"Number of cars with MPG ≥ 35: {high_mpg_count}")
# Out:
# Number of cars with MPG ≥ 35: 36

# %% [markdown]
# ### 3. What is the most common origin for cars with horsepower > 100 and weight < 3000?

# %%
#your code here
# Filter cars meeting both conditions
filtered_cars = df[(df['horsepower'] > 100) & (df['weight'] < 3000)]

# Find the most common origin
most_common_origin = filtered_cars['origin'].mode()[0]

print(f"The most common origin for cars with horsepower > 100 and weight < 3000 is: {most_common_origin}")
# Out:
# The most common origin for cars with horsepower > 100 and weight < 3000 is: usa

# %% [markdown]
# ### 4. What is the mean acceleration of cars from Japan? (rounded to 2 decimals)

# %%
#your code here
japan_accel_mean = df[df['origin'] == 'japan']['acceleration'].mean()

# Round to 2 decimal places
japan_accel_mean_rounded = round(japan_accel_mean, 2)

print(f"Mean acceleration of Japanese cars: {japan_accel_mean_rounded}")
# Out:
# Mean acceleration of Japanese cars: 16.17

# %% [markdown]
# ### 5. Which year had the highest average mpg?

# %%
#your code here
# Group by year and calculate mean MPG
yearly_avg_mpg = df.groupby('model_year')['mpg'].mean()

# Find the year with highest average MPG
best_year = yearly_avg_mpg.idxmax()
highest_avg_mpg = round(yearly_avg_mpg.max(), 2)

print(f"The year with highest average MPG is {best_year} with {highest_avg_mpg} MPG")
# Out:
# The year with highest average MPG is 80 with 33.7 MPG

# %% [markdown]
# ## *Congratulations on coming this far! Since we were having so much fun playing with this dataset, let's move towards finish line by attempting some Ungraded questions!*
#
# ### **Note:** These questions are UNGRADED, and are given as an extra exercise.

# %% [markdown]
# ### Find the car (or cars) with the best ratio of horsepower to weight among all cars that also have above-median mpg.

# %%
#your code here
# Calculate median MPG
median_mpg = dp['mpg'].median()

# Filter cars with above-median MPG
high_mpg_cars = dp[dp['mpg'] > median_mpg].copy()

# Calculate horsepower-to-weight ratio
high_mpg_cars['hp_to_weight'] = high_mpg_cars['horsepower'] / high_mpg_cars['weight']

# Find car(s) with maximum ratio
best_ratio = high_mpg_cars['hp_to_weight'].max()
best_cars = high_mpg_cars[high_mpg_cars['hp_to_weight'] == best_ratio]

# Display results
print(f"Median MPG: {median_mpg:.1f}")
print(f"\nCar(s) with best hp/weight ratio among high-MPG cars (ratio = {best_ratio:.6f}):")
print(best_cars[['name', 'horsepower', 'weight', 'mpg', 'hp_to_weight']])
# Out:
# Median MPG: 23.0
#
# Car(s) with best hp/weight ratio among high-MPG cars (ratio = 0.050582):
#                   name  horsepower  weight   mpg  hp_to_weight
# hp_to_weight
# 0.050582      bmw 2002       113.0    2234  26.0      0.050582

# %% [markdown]
# ### Design a multi-line plot using Matplotlib or Seaborn that shows the evolution of average mpg over the years, separately for each origin

# %%
# 1. Prepare the data - using actual origin labels from your dataset
avg_mpg = df.groupby(['model_year', 'origin'])['mpg'].mean().reset_index()

# 2. Create the plot
plt.figure(figsize=(12, 6))
sns.set_style("whitegrid")

# Create lineplot using origin labels directly
ax = sns.lineplot(
    data=avg_mpg,
    x='model_year',
    y='mpg',
    hue='origin',  # Uses the actual labels from your dataset
    style='origin',
    markers=True,
    dashes=False,
    linewidth=2.5,
    markersize=10,
    palette='viridis'  # Color palette that's colorblind-friendly
)

# 3. Customize the plot
plt.title("Evolution of Average MPG by Year and Origin", fontsize=16, pad=20)
plt.xlabel("Model Year", fontsize=12)
plt.ylabel("Average MPG", fontsize=12)

# Customize legend using actual origin names
plt.legend(
    title='Origin',
    fontsize=10,
    title_fontsize=12,
    frameon=True,
    loc='upper left'  # Positions legend inside plot
)

# Improve x-axis ticks
plt.xticks(avg_mpg['model_year'].unique(), rotation=45)

# Add value labels at each point if space permits
if len(avg_mpg) < 50:  # Only add labels if not too many points
    for line in ax.lines:
        for x, y in zip(line.get_xdata(), line.get_ydata()):
            ax.annotate(
                f'{y:.1f}',
                (x, y),
                textcoords="offset points",
                xytext=(0, 5),
                ha='center',
                fontsize=8
            )

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Create a Seaborn scatterplot (or PairGrid) where:
#
# X = horsepower
#
# Y = weight
#
# Color by: origin
#
# Size by: mpg
#
# Hue order = ['japan', 'europe', 'usa']
#
# Add meaningful plot titles and axis titles.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a clean copy of the data to avoid modifying original
plot_data = df.reset_index(drop=True).copy()

# Set style and figure size
plt.figure(figsize=(12, 8))
sns.set_style("whitegrid")

# Create the scatterplot with error handling
try:
    scatter = sns.scatterplot(
        data=plot_data,
        x='horsepower',
        y='weight',
        hue='origin',
        size='mpg',
        hue_order=['japan', 'europe', 'usa'],
        palette='viridis',
        sizes=(30, 200),
        alpha=0.8,
        edgecolor='black',
        linewidth=0.5
    )
    
    # Customize titles and labels
    plt.title("Vehicle Weight vs. Horsepower by Origin (Size = MPG)", fontsize=16, pad=20)
    plt.xlabel("Horsepower", fontsize=14)
    plt.ylabel("Weight (lbs)", fontsize=14)
    
    # Customize legend
    plt.legend(
        title='Origin / MPG',
        bbox_to_anchor=(1.05, 1),
        loc='upper left',
        frameon=True
    )
    
    plt.tight_layout()
    plt.show()

except ValueError as e:
    print(f"Plotting error: {e}")
    print("\nDebugging info:")
    print(f"Duplicate indices: {df.index.duplicated().sum()}")
    print(f"Null values in key columns:")
    print(df[['horsepower', 'weight', 'mpg', 'origin']].isnull().sum())

# %% [markdown]
# ### We define a “consistent” car model as one that was produced over multiple years and had very low variation in mpg across those years (standard deviation < 1.0).
#
# Tasks:
#
# Identify car names that appear in more than one model_year.
#
# For each such name, compute the standard deviation of mpg across years.
#
# Return the car(s) with the lowest variation in mpg, among those with at least 2 appearances and std(mpg) < 1.0.
#
# Report the model name(s), number of appearances, and the average mpg.
#
# Bonus:
# Sort the result by number of appearances (descending), then mpg (descending).

# %%
#your code here
import pandas as pd

# 1. Filter cars that appear in multiple years
multi_year_cars = df.groupby('name').filter(lambda x: len(x) > 1)

# 2. Calculate statistics for each model
consistency_stats = (multi_year_cars.groupby('name')
                    .agg(
                        appearances=('mpg', 'size'),
                        mpg_std=('mpg', 'std'),
                        avg_mpg=('mpg', 'mean')
                    )
                    .reset_index())

# 3. Filter for consistent models (std < 1.0)
consistent_models = consistency_stats[
    (consistency_stats['mpg_std'] < 1.0) & 
    (consistency_stats['appearances'] >= 2)
]

# 4. Sort and get results (Bonus sorting)
result = (consistent_models
          .sort_values(['appearances', 'avg_mpg'], ascending=[False, False])
          .reset_index(drop=True))

# 5. Format and display the output
if not result.empty:
    print("Most Consistent Car Models (lowest MPG variation across years):")
    print(result[['name', 'appearances', 'avg_mpg', 'mpg_std']]
          .rename(columns={
              'name': 'Model',
              'appearances': 'Years Produced',
              'avg_mpg': 'Average MPG',
              'mpg_std': 'MPG Standard Deviation'
          })
          .to_string(index=False))
else:
    print("No models meet the consistency criteria (std < 1.0 across multiple years)")
# Out:
# Most Consistent Car Models (lowest MPG variation across years):
#                     Model  Years Produced  Average MPG  MPG Standard Deviation
#          ford galaxie 500               3    14.333333                0.577350
#         plymouth fury iii               3    14.333333                0.577350
#       toyota corolla 1200               2    31.500000                0.707107
#                 mazda 626               2    31.450000                0.212132
#         volkswagen rabbit               2    29.250000                0.353553
#              datsun pl510               2    27.000000                0.000000
#                 saab 99le               2    24.500000                0.707107
#            toyota mark ii               2    19.500000                0.707107
#               dodge aspen               2    18.850000                0.353553
# chevrolet chevelle malibu               2    17.500000                0.707107
#          amc matador (sw)               2    14.500000                0.707107
#     ford gran torino (sw)               2    13.500000                0.707107
#                  ford ltd               2    13.500000                0.707107

# %% [markdown]
# ![OIP.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Congratulations on completing the race. Kudos to you. Looking forward to meet you in next week.**
